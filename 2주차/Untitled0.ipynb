# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(-10000,10000)
y = (X/10000) * (X/10000)+0.05

# %%
plt.plot(X, y)

plt.axis([-10000,10000,-0.1,1.1])
plt.show()

# %%
 X
# Out:
# array([-3, -2, -1,  0,  1,  2])

# %%
x = np.array(range(0,11))
y2 = [b for b in range(11)]

plt.plot(x, y2)
plt.show()

# %%
X = np.array(range(-3,3))
y = X*X + 0.2

plt.plot(X, y)

plt.axis([-5,5,0,4.0])
plt.show()
